# %% [markdown]
# <a href="https://colab.research.google.com/github/chaseScallons/Classification-Practice/blob/main/Tensorflow_Classification_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_circles
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# Intitialize 1000 samples
n_samples = 1000

# Create data for classification
X, y = make_circles(n_samples=n_samples,
                    noise=0.03,
                    random_state=34) # Sets seed for reproducability

# %%
# Structure
circles = pd.DataFrame({"X0": X[:, 0], "X1": X[:, 1], "Label": y})

# %%
# Visualization
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu)

# %%
len(X), len(y)
# Out:
# (1000, 1000)

# %%
from tensorflow.python import metrics
# Model (1)

tf.random.set_seed(34)

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_1.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["accuracy"])

model_1.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 32/32 [==============================] - 0s 970us/step - loss: 2.8140 - accuracy: 0.4750
# Epoch 2/5
# 32/32 [==============================] - 0s 925us/step - loss: 0.7517 - accuracy: 0.4930
# Epoch 3/5
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7105 - accuracy: 0.4930
# Epoch 4/5
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.4890
# Epoch 5/5
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6962 - accuracy: 0.5100

# %%
model_1.fit(X, y, epochs=200, verbose=0)

# %%
model_1.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.5000
# [0.6932567358016968, 0.5]

# %%
# Model (2)

tf.random.set_seed(34)

model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(1),
    tf.keras.layers.Dense(1)
])

model_2.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["accuracy"])

model_2.fit(X, y, epochs=100, verbose=0)

# %%
model_2.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6937 - accuracy: 0.4960
# [0.6936653852462769, 0.4959999918937683]

# %%
# Model (3)
tf.random.set_seed(34)

model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])

model_3.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

model_3.fit(X, y, epochs=100, verbose=0)

# %%
model_3.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 991us/step - loss: 0.6932 - accuracy: 0.4980
# [0.6931593418121338, 0.49799999594688416]
